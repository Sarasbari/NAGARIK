# %% [markdown]
# # YOLOv8 Training Notebook — Nagarik Issue Classifier
#
# This notebook trains a custom YOLOv8 model for civic issue classification.
# Run on Google Colab with GPU runtime.
#
# ## Setup
# ```
# pip install ultralytics roboflow
# ```

# %%
# TODO: Add training pipeline
# 1. Download dataset from Roboflow
# 2. Train YOLOv8 model
# 3. Export best.pt weights
# 4. Upload to ai/models/best.pt
